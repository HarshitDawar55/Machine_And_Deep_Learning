# %% [markdown]
# # DBSCAN spatial clustering on randomly generated data by `Mr. Harshit Dawar`!

# %% [markdown]
# ## Importing required libraries!

# %%
import numpy as np 
from sklearn.cluster import DBSCAN 
from sklearn.datasets.samples_generator import make_blobs 
from sklearn.preprocessing import StandardScaler 
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples = 1575, centers = [[1,2], [5,7], [9,11]], cluster_std = 0.9)

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15,9))
plt.scatter(X[:, 0], X[:, 1], c = y, cmap = "summer")
plt.show()

# %%
X_transformed = StandardScaler().fit_transform(X)

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15,9))
plt.scatter(X_transformed[:, 0], X_transformed[:, 1], c = y, cmap = "summer")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_transformed2 = MinMaxScaler().fit_transform(X)

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15,9))
plt.scatter(X_transformed2[:, 0], X_transformed2[:, 1], c = y, cmap = "summer")
plt.show()

# %%
density_based_clustering = DBSCAN(eps = 0.03, min_samples = 7)
density_based_clustering.fit(X_transformed2)
# Out:
# DBSCAN(algorithm='auto', eps=0.03, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=7, n_jobs=None, p=None)

# %%
density_based_clustering.labels_
# Out:
# array([0, 1, 0, ..., 0, 0, 2])

# %%
np.unique(density_based_clustering.labels_, return_counts=True)
# Out:
# (array([-1,  0,  1,  2]), array([ 83, 494, 494, 504]))

# %%
set(density_based_clustering.labels_)
unique_value = set(density_based_clustering.labels_)

unique_value
# Out:
# {-1, 0, 1, 2}

# %%
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_value)))

# %%
l = density_based_clustering.labels_

# %%
plt.figure(figsize=(15,9))


plt.scatter(X[l != -1, 0], X[l != -1, 1], c = "lightgreen", alpha=1, label = "clustered points")
plt.scatter(X[l == -1, 0], X[l == -1, 1], c = "red", alpha=1, label = "outliers")
plt.legend()
plt.xticks([])
plt.yticks([])
plt.show()
